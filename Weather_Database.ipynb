# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Create a set of 2,000 random latitudes and longitudes

# %%
# Create a nandom set Latitude from -90 to 90 deg
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
# Create a random set of longitude from -180 to + 180 deg
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)

# Save the latitude and longitudes in a coordinate list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the Nearest City from ciipy

# %%
# Import citipy module to get the nearest city based on latitude and longitude.
from citipy import citipy

# Create a list for holding city names.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add the name in the cities list.
    if city not in cities:
        cities.append(city)
# Check if there are sufficient number of cities
len(cities)
# Out:
# 772

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Import requests and API keys to request the API
import requests
from config import weather_api_key

# Import the datetime library to convert the time stamp
from datetime import datetime

# API call from OpenWeatherMap url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %% [markdown]
# ### Build empty cell to hold data and construct the data retrieval

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging of city names.
print("Beginning Data Retrieval         ")
print ("---------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ---------------------------------

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    #Group cities in set of 50 for logging purposes.
    if (i %  50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities:
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
                
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping ...")
        pass
# Indicate that the Data loading s complete.
print("----------------------------------")
print("Data Retrieval Complete")
print("----------------------------------")
# Out:
# Processing Record1 of Set 1 | arraial do cabo
# Processing Record2 of Set 1 | griffith
# Processing Record3 of Set 1 | grand river south east
# City not found. Skipping ...
# Processing Record4 of Set 1 | mataura
# Processing Record5 of Set 1 | flinders
# Processing Record6 of Set 1 | georgetown
# Processing Record7 of Set 1 | hermanus
# Processing Record8 of Set 1 | vila velha
# Processing Record9 of Set 1 | krasnoselkup
# Processing Record10 of Set 1 | kavieng
# Processing Record11 of Set 1 | bucerias
# Processing Record12 of Set 1 | adrar
# Processing Record13 of Set 1 | butaritari
# Processing Record14 of Set 1 | beyneu
# Processing Record15 of Set 1 | khatanga
# Processing Record16 of Set 1 | pangnirtung
# Processing Record17 of Set 1 | mount isa
# Processing Record18 of Set 1 | yellowknife
# Processing Record19 of Set 1 | jizan
# Processing Record20 of Set 1 | padang
# Processing Record21 of Set 1 | bambous virieux
# Processing Record22 of Set 1 | kodiak
# Processing Record23 of Set 1 | albany
# Processing Record24 of Set 1 | auki
# Processing Record25 of Set 1 | gewane
# Processing Record26 of Set 1 | port alfred
# Processing Record27 of Set 1 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record28 of Set 1 | tasiilaq
# Processing Record29 of Set 1 | port blair
# Processing Record30 of Set 1 | ushuaia
# Processing Record31 of Set 1 | hilo
# Processing Record32 of Set 1 | umm kaddadah
# Processing Record33 of Set 1 | ngukurr
# City not found. Skipping ...
# Processing Record34 of Set 1 | trafaria
# Processing Record35 of Set 1 | puerto maldonado
# Processing Record36 of Set 1 | rikitea
# Processing Record37 of Set 1 | tumannyy
# City not found. Skipping ...
# Processing Record38 of Set 1 | lata
# Processing Record39 of Set 1 | siyabuswa
# Processing Record40 of Set 1 | ribeira grande
# Processing Record41 of Set 1 | kapaa
# Processing Record42 of Set 1 | bluff
# Processing Record43 of Set 1 | arraias
# Processing Record44 of Set 1 | lompoc
# Processing Record45 of Set 1 | vaini
# Processing Record46 of Set 1 | abu kamal
# Processing Record47 of Set 1 | castro
# Processing Record48 of Set 1 | usinsk
# Processing Record49 of Set 1 | conceicao do araguaia
# Processing Record50 of Set 1 | jamestown
# Processing Record1 of Set 2 | saskylakh
# Processing Record2 of Set 2 | horqueta
# Processing Record3 of Set 2 | chicama
# Processing Record4 of Set 2 | liwale
# Processing Record5 of Set 2 | maitum
# Processing Record6 of Set 2 | kahului
# Processing Record7 of Set 2 | broome
# Processing Record8 of Set 2 | barentsburg
# City not found. Skipping ...
# Processing Record9 of Set 2 | san cristobal
# Processing Record10 of Set 2 | bredasdorp
# Processing Record11 of Set 2 | tuatapere
# Processing Record12 of Set 2 | luderitz
# Processing Record13 of Set 2 | lebu
# Processing Record14 of Set 2 | cidreira
# Processing Record15 of Set 2 | lavrentiya
# Processing Record16 of Set 2 | egvekinot
# Processing Record17 of Set 2 | cherskiy
# Processing Record18 of Set 2 | souillac
# Processing Record19 of Set 2 | lucapa
# Processing Record20 of Set 2 | itoman
# Processing Record21 of Set 2 | carnarvon
# Processing Record22 of Set 2 | meulaboh
# Processing Record23 of Set 2 | port lincoln
# Processing Record24 of Set 2 | halalo
# City not found. Skipping ...
# Processing Record25 of Set 2 | bathsheba
# Processing Record26 of Set 2 | taltal
# Processing Record27 of Set 2 | east london
# Processing Record28 of Set 2 | humberto de campos
# Processing Record29 of Set 2 | port-cartier
# Processing Record30 of Set 2 | xixiang
# Processing Record31 of Set 2 | alekseyevka
# Processing Record32 of Set 2 | chipinge
# Processing Record33 of Set 2 | kolpashevo
# Processing Record34 of Set 2 | atuona
# Processing Record35 of Set 2 | buzias
# Processing Record36 of Set 2 | taolanaro
# City not found. Skipping ...
# Processing Record37 of Set 2 | mabaruma
# Processing Record38 of Set 2 | oktyabrskoye
# Processing Record39 of Set 2 | caravelas
# Processing Record40 of Set 2 | cayenne
# Processing Record41 of Set 2 | vila
# Processing Record42 of Set 2 | suntar
# Processing Record43 of Set 2 | shingu
# Processing Record44 of Set 2 | esperance
# Processing Record45 of Set 2 | vila franca do campo
# Processing Record46 of Set 2 | kupang
# Processing Record47 of Set 2 | sanmenxia
# Processing Record48 of Set 2 | punta arenas
# Processing Record49 of Set 2 | hobart
# Processing Record50 of Set 2 | barrow
# Processing Record1 of Set 3 | broken hill
# Processing Record2 of Set 3 | tottori
# Processing Record3 of Set 3 | vaitupu
# City not found. Skipping ...
# Processing Record4 of Set 3 | makarov
# Processing Record5 of Set 3 | north bend
# Processing Record6 of Set 3 | corinto
# Processing Record7 of Set 3 | tadine
# Processing Record8 of Set 3 | darhan
# Processing Record9 of Set 3 | mar del plata
# Processing Record10 of Set 3 | palabuhanratu
# City not found. Skipping ...
# Processing Record11 of Set 3 | orlik
# Processing Record12 of Set 3 | samoded
# Processing Record13 of Set 3 | mount gambier
# Processing Record14 of Set 3 | soure
# Processing Record15 of Set 3 | graaff-reinet
# Processing Record16 of Set 3 | alenquer
# Processing Record17 of Set 3 | salalah
# Processing Record18 of Set 3 | busselton
# Processing Record19 of Set 3 | cape town
# Processing Record20 of Set 3 | namatanai
# Processing Record21 of Set 3 | el porvenir
# Processing Record22 of Set 3 | tiksi
# Processing Record23 of Set 3 | grand-santi
# Processing Record24 of Set 3 | upernavik
# Processing Record25 of Set 3 | beringovskiy
# Processing Record26 of Set 3 | berdigestyakh
# Processing Record27 of Set 3 | abeche
# Processing Record28 of Set 3 | rabak
# Processing Record29 of Set 3 | westport
# Processing Record30 of Set 3 | hoquiam
# Processing Record31 of Set 3 | mangaratiba
# Processing Record32 of Set 3 | stolin
# Processing Record33 of Set 3 | puerto ayora
# Processing Record34 of Set 3 | bethel
# Processing Record35 of Set 3 | ilulissat
# Processing Record36 of Set 3 | chuy
# Processing Record37 of Set 3 | longyearbyen
# Processing Record38 of Set 3 | kapuskasing
# Processing Record39 of Set 3 | zyryanka
# Processing Record40 of Set 3 | dikson
# Processing Record41 of Set 3 | litovko
# Processing Record42 of Set 3 | quatre cocos
# Processing Record43 of Set 3 | bandarbeyla
# Processing Record44 of Set 3 | san-pedro
# Processing Record45 of Set 3 | pevek
# Processing Record46 of Set 3 | aykhal
# Processing Record47 of Set 3 | faanui
# Processing Record48 of Set 3 | cikupa
# Processing Record49 of Set 3 | sorland
# Processing Record50 of Set 3 | bitung
# Processing Record1 of Set 4 | thompson
# Processing Record2 of Set 4 | saint george
# Processing Record3 of Set 4 | nikolskoye
# Processing Record4 of Set 4 | aksu
# Processing Record5 of Set 4 | havre-saint-pierre
# Processing Record6 of Set 4 | mys shmidta
# City not found. Skipping ...
# Processing Record7 of Set 4 | ponta do sol
# Processing Record8 of Set 4 | byron bay
# Processing Record9 of Set 4 | rio grande
# Processing Record10 of Set 4 | belushya guba
# City not found. Skipping ...
# Processing Record11 of Set 4 | vestmannaeyjar
# Processing Record12 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record13 of Set 4 | aylmer
# Processing Record14 of Set 4 | airai
# Processing Record15 of Set 4 | deputatskiy
# Processing Record16 of Set 4 | ozernovskiy
# Processing Record17 of Set 4 | sitka
# Processing Record18 of Set 4 | kutum
# Processing Record19 of Set 4 | constitucion
# Processing Record20 of Set 4 | namibe
# Processing Record21 of Set 4 | komsomolskiy
# Processing Record22 of Set 4 | new norfolk
# Processing Record23 of Set 4 | clyde river
# Processing Record24 of Set 4 | gorontalo
# Processing Record25 of Set 4 | korla
# Processing Record26 of Set 4 | mayo
# Processing Record27 of Set 4 | baishishan
# Processing Record28 of Set 4 | burica
# City not found. Skipping ...
# Processing Record29 of Set 4 | kapoeta
# Processing Record30 of Set 4 | geraldton
# Processing Record31 of Set 4 | humaita
# Processing Record32 of Set 4 | ampanihy
# Processing Record33 of Set 4 | bengkulu
# Processing Record34 of Set 4 | sentyabrskiy
# City not found. Skipping ...
# Processing Record35 of Set 4 | campo gobierno
# Processing Record36 of Set 4 | terra santa
# Processing Record37 of Set 4 | atasu
# Processing Record38 of Set 4 | hervey bay
# Processing Record39 of Set 4 | qaanaaq
# Processing Record40 of Set 4 | rungata
# City not found. Skipping ...
# Processing Record41 of Set 4 | xiutetelco
# City not found. Skipping ...
# Processing Record42 of Set 4 | qasigiannguit
# Processing Record43 of Set 4 | waddan
# Processing Record44 of Set 4 | yuzhnyy
# Processing Record45 of Set 4 | attawapiskat
# City not found. Skipping ...
# Processing Record46 of Set 4 | nanortalik
# Processing Record47 of Set 4 | labutta
# City not found. Skipping ...
# Processing Record48 of Set 4 | elat
# Processing Record49 of Set 4 | jhusi
# Processing Record50 of Set 4 | verkhoyansk
# Processing Record1 of Set 5 | marzuq
# Processing Record2 of Set 5 | chapayeve
# Processing Record3 of Set 5 | umzimvubu
# City not found. Skipping ...
# Processing Record4 of Set 5 | mehamn
# Processing Record5 of Set 5 | am timan
# Processing Record6 of Set 5 | coihaique
# Processing Record7 of Set 5 | mareeba
# Processing Record8 of Set 5 | miquelon
# Processing Record9 of Set 5 | vanimo
# Processing Record10 of Set 5 | platanos
# Processing Record11 of Set 5 | mahebourg
# Processing Record12 of Set 5 | dunstable
# Processing Record13 of Set 5 | los llanos de aridane
# Processing Record14 of Set 5 | atar
# Processing Record15 of Set 5 | maningrida
# Processing Record16 of Set 5 | sovetskiy
# Processing Record17 of Set 5 | mwanza
# Processing Record18 of Set 5 | pitimbu
# Processing Record19 of Set 5 | tallahassee
# Processing Record20 of Set 5 | adunatii-copaceni
# City not found. Skipping ...
# Processing Record21 of Set 5 | havelock
# Processing Record22 of Set 5 | mazatlan
# Processing Record23 of Set 5 | nishihara
# Processing Record24 of Set 5 | kousseri
# Processing Record25 of Set 5 | okha
# Processing Record26 of Set 5 | bilibino
# Processing Record27 of Set 5 | manta
# Processing Record28 of Set 5 | hithadhoo
# Processing Record29 of Set 5 | muisne
# Processing Record30 of Set 5 | palmer
# Processing Record31 of Set 5 | jobner
# Processing Record32 of Set 5 | merauke
# Processing Record33 of Set 5 | benguela
# Processing Record34 of Set 5 | barhi
# Processing Record35 of Set 5 | pinas
# Processing Record36 of Set 5 | doctor pedro p. pena
# City not found. Skipping ...
# Processing Record37 of Set 5 | uige
# Processing Record38 of Set 5 | sao filipe
# Processing Record39 of Set 5 | vilhena
# Processing Record40 of Set 5 | tsihombe
# City not found. Skipping ...
# Processing Record41 of Set 5 | tubruq
# City not found. Skipping ...
# Processing Record42 of Set 5 | sistranda
# Processing Record43 of Set 5 | sobolevo
# Processing Record44 of Set 5 | kuche
# City not found. Skipping ...
# Processing Record45 of Set 5 | yeppoon
# Processing Record46 of Set 5 | springdale
# Processing Record47 of Set 5 | samusu
# City not found. Skipping ...
# Processing Record48 of Set 5 | lazaro cardenas
# Processing Record49 of Set 5 | alofi
# Processing Record50 of Set 5 | marsabit
# Processing Record1 of Set 6 | temaraia
# City not found. Skipping ...
# Processing Record2 of Set 6 | ostrovnoy
# Processing Record3 of Set 6 | surin
# Processing Record4 of Set 6 | leningradskiy
# Processing Record5 of Set 6 | gospic
# Processing Record6 of Set 6 | manaus
# Processing Record7 of Set 6 | pervomayskoye
# Processing Record8 of Set 6 | villazon
# Processing Record9 of Set 6 | pozo colorado
# Processing Record10 of Set 6 | yingzhong
# City not found. Skipping ...
# Processing Record11 of Set 6 | skibotn
# Processing Record12 of Set 6 | kinwat
# Processing Record13 of Set 6 | santiago del estero
# Processing Record14 of Set 6 | rongcheng
# Processing Record15 of Set 6 | vidisha
# Processing Record16 of Set 6 | kaitangata
# Processing Record17 of Set 6 | longlac
# City not found. Skipping ...
# Processing Record18 of Set 6 | oussouye
# Processing Record19 of Set 6 | sakakah
# Processing Record20 of Set 6 | sorvag
# City not found. Skipping ...
# Processing Record21 of Set 6 | abu dhabi
# Processing Record22 of Set 6 | anadyr
# Processing Record23 of Set 6 | gao
# Processing Record24 of Set 6 | tuktoyaktuk
# Processing Record25 of Set 6 | grants pass
# Processing Record26 of Set 6 | sechura
# Processing Record27 of Set 6 | uhingen
# Processing Record28 of Set 6 | lorengau
# Processing Record29 of Set 6 | klaksvik
# Processing Record30 of Set 6 | erdemli
# Processing Record31 of Set 6 | okhotsk
# Processing Record32 of Set 6 | tabiauea
# City not found. Skipping ...
# Processing Record33 of Set 6 | srednekolymsk
# Processing Record34 of Set 6 | navrongo
# Processing Record35 of Set 6 | lewistown
# Processing Record36 of Set 6 | corn island
# Processing Record37 of Set 6 | erdenet
# Processing Record38 of Set 6 | bernalillo
# Processing Record39 of Set 6 | bima
# Processing Record40 of Set 6 | arrecife
# Processing Record41 of Set 6 | karamea
# City not found. Skipping ...
# Processing Record42 of Set 6 | yulara
# Processing Record43 of Set 6 | colonial park
# Processing Record44 of Set 6 | gashua
# Processing Record45 of Set 6 | boende
# Processing Record46 of Set 6 | cabedelo
# Processing Record47 of Set 6 | stovring
# Processing Record48 of Set 6 | najran
# Processing Record49 of Set 6 | haibowan
# City not found. Skipping ...
# Processing Record50 of Set 6 | kurumkan
# Processing Record1 of Set 7 | bocaiuva
# Processing Record2 of Set 7 | saint-philippe
# Processing Record3 of Set 7 | norman wells
# Processing Record4 of Set 7 | aklavik
# Processing Record5 of Set 7 | urengoy
# Processing Record6 of Set 7 | nome
# Processing Record7 of Set 7 | sola
# Processing Record8 of Set 7 | avarua
# Processing Record9 of Set 7 | asau
# Processing Record10 of Set 7 | bessonovka
# Processing Record11 of Set 7 | hasaki
# Processing Record12 of Set 7 | lichtenburg
# Processing Record13 of Set 7 | sembakung
# Processing Record14 of Set 7 | talnakh
# Processing Record15 of Set 7 | port augusta
# Processing Record16 of Set 7 | samalaeulu
# City not found. Skipping ...
# Processing Record17 of Set 7 | fort nelson
# Processing Record18 of Set 7 | smithers
# Processing Record19 of Set 7 | kunya
# Processing Record20 of Set 7 | chokurdakh
# Processing Record21 of Set 7 | mendoza
# Processing Record22 of Set 7 | dubrovnik
# Processing Record23 of Set 7 | wajima
# Processing Record24 of Set 7 | clearlake
# Processing Record25 of Set 7 | ust-maya
# Processing Record26 of Set 7 | hvammstangi
# City not found. Skipping ...
# Processing Record27 of Set 7 | saint-augustin
# Processing Record28 of Set 7 | erenhot
# Processing Record29 of Set 7 | chumikan
# Processing Record30 of Set 7 | tilichiki
# Processing Record31 of Set 7 | koubia
# Processing Record32 of Set 7 | kalaleh
# Processing Record33 of Set 7 | yarmouth
# Processing Record34 of Set 7 | camacha
# Processing Record35 of Set 7 | saint anthony
# Processing Record36 of Set 7 | mezen
# Processing Record37 of Set 7 | strezhevoy
# Processing Record38 of Set 7 | karaul
# City not found. Skipping ...
# Processing Record39 of Set 7 | stryn
# Processing Record40 of Set 7 | alice springs
# Processing Record41 of Set 7 | dafeng
# Processing Record42 of Set 7 | saint paul
# Processing Record43 of Set 7 | zhuhai
# Processing Record44 of Set 7 | chardara
# Processing Record45 of Set 7 | yerofey pavlovich
# Processing Record46 of Set 7 | san policarpo
# Processing Record47 of Set 7 | artigas
# Processing Record48 of Set 7 | litoral del san juan
# City not found. Skipping ...
# Processing Record49 of Set 7 | kruisfontein
# Processing Record50 of Set 7 | wenchi
# Processing Record1 of Set 8 | bud
# Processing Record2 of Set 8 | ust-nera
# Processing Record3 of Set 8 | satitoa
# City not found. Skipping ...
# Processing Record4 of Set 8 | merritt island
# Processing Record5 of Set 8 | laguna
# Processing Record6 of Set 8 | marawi
# Processing Record7 of Set 8 | cambridge
# Processing Record8 of Set 8 | yuncheng
# Processing Record9 of Set 8 | dalby
# Processing Record10 of Set 8 | iqaluit
# Processing Record11 of Set 8 | stoughton
# Processing Record12 of Set 8 | victoria
# Processing Record13 of Set 8 | fairbanks
# Processing Record14 of Set 8 | sao joao da barra
# Processing Record15 of Set 8 | mpika
# Processing Record16 of Set 8 | the valley
# Processing Record17 of Set 8 | lapi
# Processing Record18 of Set 8 | carolina
# Processing Record19 of Set 8 | utiroa
# City not found. Skipping ...
# Processing Record20 of Set 8 | kendari
# Processing Record21 of Set 8 | marsh harbour
# Processing Record22 of Set 8 | torbay
# Processing Record23 of Set 8 | ridgecrest
# Processing Record24 of Set 8 | nakonde
# Processing Record25 of Set 8 | pacific grove
# Processing Record26 of Set 8 | buala
# Processing Record27 of Set 8 | walvis bay
# Processing Record28 of Set 8 | port hedland
# Processing Record29 of Set 8 | sembe
# Processing Record30 of Set 8 | huarmey
# Processing Record31 of Set 8 | prestea
# Processing Record32 of Set 8 | gangotri
# City not found. Skipping ...
# Processing Record33 of Set 8 | whitianga
# Processing Record34 of Set 8 | tabou
# Processing Record35 of Set 8 | iguape
# Processing Record36 of Set 8 | porto franco
# Processing Record37 of Set 8 | bar harbor
# Processing Record38 of Set 8 | formoso do araguaia
# City not found. Skipping ...
# Processing Record39 of Set 8 | itapora
# Processing Record40 of Set 8 | san patricio
# Processing Record41 of Set 8 | bagdarin
# Processing Record42 of Set 8 | meyungs
# City not found. Skipping ...
# Processing Record43 of Set 8 | yerbogachen
# Processing Record44 of Set 8 | fuxin
# Processing Record45 of Set 8 | sangmelima
# Processing Record46 of Set 8 | necochea
# Processing Record47 of Set 8 | bantou
# Processing Record48 of Set 8 | santa cruz
# Processing Record49 of Set 8 | karakendzha
# City not found. Skipping ...
# Processing Record50 of Set 8 | sarkikaraagac
# Processing Record1 of Set 9 | jacareacanga
# Processing Record2 of Set 9 | narsaq
# Processing Record3 of Set 9 | birao
# Processing Record4 of Set 9 | sangar
# Processing Record5 of Set 9 | leh
# Processing Record6 of Set 9 | nevsehir
# Processing Record7 of Set 9 | goderich
# Processing Record8 of Set 9 | altay
# Processing Record9 of Set 9 | san cosme y damian
# Processing Record10 of Set 9 | kirakira
# Processing Record11 of Set 9 | sinnamary
# Processing Record12 of Set 9 | sumbawa
# City not found. Skipping ...
# Processing Record13 of Set 9 | brainerd
# Processing Record14 of Set 9 | kiunga
# Processing Record15 of Set 9 | vega de alatorre
# Processing Record16 of Set 9 | roswell
# Processing Record17 of Set 9 | majene
# Processing Record18 of Set 9 | haines junction
# Processing Record19 of Set 9 | lasa
# Processing Record20 of Set 9 | madera
# Processing Record21 of Set 9 | chake chake
# Processing Record22 of Set 9 | severo-yeniseyskiy
# Processing Record23 of Set 9 | knin
# Processing Record24 of Set 9 | saint-pierre
# Processing Record25 of Set 9 | plouzane
# Processing Record26 of Set 9 | rakitnoye
# Processing Record27 of Set 9 | kragero
# Processing Record28 of Set 9 | san quintin
# Processing Record29 of Set 9 | margate
# Processing Record30 of Set 9 | careiro da varzea
# Processing Record31 of Set 9 | flin flon
# Processing Record32 of Set 9 | obo
# Processing Record33 of Set 9 | ngunguru
# Processing Record34 of Set 9 | temryuk
# Processing Record35 of Set 9 | nigde
# Processing Record36 of Set 9 | hay river
# Processing Record37 of Set 9 | iwaki
# Processing Record38 of Set 9 | ashland
# Processing Record39 of Set 9 | scarborough
# Processing Record40 of Set 9 | olafsvik
# Processing Record41 of Set 9 | chutove
# Processing Record42 of Set 9 | torbat-e jam
# Processing Record43 of Set 9 | aktau
# Processing Record44 of Set 9 | kuminskiy
# Processing Record45 of Set 9 | samarai
# Processing Record46 of Set 9 | batemans bay
# Processing Record47 of Set 9 | aksarka
# Processing Record48 of Set 9 | port pirie
# Processing Record49 of Set 9 | virginia beach
# Processing Record50 of Set 9 | okhtyrka
# Processing Record1 of Set 10 | san andres
# Processing Record2 of Set 10 | marrakesh
# Processing Record3 of Set 10 | buraydah
# Processing Record4 of Set 10 | husavik
# Processing Record5 of Set 10 | kazalinsk
# City not found. Skipping ...
# Processing Record6 of Set 10 | pleasant prairie
# Processing Record7 of Set 10 | santa vitoria do palmar
# Processing Record8 of Set 10 | tura
# Processing Record9 of Set 10 | palauig
# Processing Record10 of Set 10 | megion
# Processing Record11 of Set 10 | zhigansk
# Processing Record12 of Set 10 | temir
# Processing Record13 of Set 10 | bayanday
# Processing Record14 of Set 10 | leshukonskoye
# Processing Record15 of Set 10 | arawa
# Processing Record16 of Set 10 | cockburn harbour
# City not found. Skipping ...
# Processing Record17 of Set 10 | faya
# Processing Record18 of Set 10 | pochutla
# Processing Record19 of Set 10 | hofn
# Processing Record20 of Set 10 | kirillov
# Processing Record21 of Set 10 | ngaoundere
# Processing Record22 of Set 10 | mayang imphal
# Processing Record23 of Set 10 | saldanha
# Processing Record24 of Set 10 | saleaula
# City not found. Skipping ...
# Processing Record25 of Set 10 | boddam
# Processing Record26 of Set 10 | aripuana
# Processing Record27 of Set 10 | sorong
# Processing Record28 of Set 10 | dawson creek
# Processing Record29 of Set 10 | llangefni
# Processing Record30 of Set 10 | yanchukan
# City not found. Skipping ...
# Processing Record31 of Set 10 | zhezkazgan
# Processing Record32 of Set 10 | ancud
# Processing Record33 of Set 10 | emerald
# Processing Record34 of Set 10 | tarata
# Processing Record35 of Set 10 | balagansk
# Processing Record36 of Set 10 | hohhot
# Processing Record37 of Set 10 | rawson
# Processing Record38 of Set 10 | mochicahui
# Processing Record39 of Set 10 | baykit
# Processing Record40 of Set 10 | ankara
# Processing Record41 of Set 10 | provideniya
# Processing Record42 of Set 10 | bur gabo
# City not found. Skipping ...
# Processing Record43 of Set 10 | caloundra
# Processing Record44 of Set 10 | camargo
# Processing Record45 of Set 10 | normandin
# Processing Record46 of Set 10 | guerrero negro
# Processing Record47 of Set 10 | te anau
# Processing Record48 of Set 10 | hambantota
# Processing Record49 of Set 10 | ndele
# Processing Record50 of Set 10 | san pedro
# Processing Record1 of Set 11 | college
# Processing Record2 of Set 11 | perth
# Processing Record3 of Set 11 | warqla
# City not found. Skipping ...
# Processing Record4 of Set 11 | qaqortoq
# Processing Record5 of Set 11 | drovyanaya
# Processing Record6 of Set 11 | luganville
# Processing Record7 of Set 11 | nyurba
# Processing Record8 of Set 11 | campos do jordao
# Processing Record9 of Set 11 | grand centre
# City not found. Skipping ...
# Processing Record10 of Set 11 | hondo
# Processing Record11 of Set 11 | kifri
# Processing Record12 of Set 11 | luanshya
# Processing Record13 of Set 11 | soe
# Processing Record14 of Set 11 | grindavik
# Processing Record15 of Set 11 | mubende
# Processing Record16 of Set 11 | dhola
# Processing Record17 of Set 11 | kijang
# Processing Record18 of Set 11 | seymchan
# Processing Record19 of Set 11 | palaikastron
# Processing Record20 of Set 11 | tambura
# Processing Record21 of Set 11 | zapolyarnyy
# Processing Record22 of Set 11 | camacari
# Processing Record23 of Set 11 | manado
# Processing Record24 of Set 11 | kenora
# Processing Record25 of Set 11 | amderma
# City not found. Skipping ...
# Processing Record26 of Set 11 | beaverlodge
# Processing Record27 of Set 11 | kshenskiy
# Processing Record28 of Set 11 | bandar-e lengeh
# Processing Record29 of Set 11 | dronninglund
# Processing Record30 of Set 11 | anlu
# Processing Record31 of Set 11 | ahipara
# Processing Record32 of Set 11 | puerto del rosario
# Processing Record33 of Set 11 | tigil
# Processing Record34 of Set 11 | pemangkat
# Processing Record35 of Set 11 | maua
# Processing Record36 of Set 11 | malwan
# City not found. Skipping ...
# Processing Record37 of Set 11 | burgos
# Processing Record38 of Set 11 | kazuno
# Processing Record39 of Set 11 | kavant
# City not found. Skipping ...
# Processing Record40 of Set 11 | buchanan
# Processing Record41 of Set 11 | athabasca
# Processing Record42 of Set 11 | bonthe
# Processing Record43 of Set 11 | paamiut
# Processing Record44 of Set 11 | bubaque
# Processing Record45 of Set 11 | bodden town
# Processing Record46 of Set 11 | oga
# Processing Record47 of Set 11 | cartagena
# Processing Record48 of Set 11 | sturgeon bay
# Processing Record49 of Set 11 | pokrovsk
# Processing Record50 of Set 11 | khash
# Processing Record1 of Set 12 | south sioux city
# Processing Record2 of Set 12 | yola
# Processing Record3 of Set 12 | la ronge
# Processing Record4 of Set 12 | nouadhibou
# Processing Record5 of Set 12 | bolshiye uki
# City not found. Skipping ...
# Processing Record6 of Set 12 | zaysan
# Processing Record7 of Set 12 | kungurtug
# Processing Record8 of Set 12 | vangaindrano
# Processing Record9 of Set 12 | aberdeen
# Processing Record10 of Set 12 | hami
# Processing Record11 of Set 12 | yaan
# Processing Record12 of Set 12 | daru
# Processing Record13 of Set 12 | rovaniemi
# Processing Record14 of Set 12 | tashtyp
# Processing Record15 of Set 12 | kushima
# Processing Record16 of Set 12 | xuanzhou
# Processing Record17 of Set 12 | labuhan
# Processing Record18 of Set 12 | kintampo
# Processing Record19 of Set 12 | nouakchott
# Processing Record20 of Set 12 | half moon bay
# Processing Record21 of Set 12 | nsunga
# Processing Record22 of Set 12 | saurimo
# Processing Record23 of Set 12 | conde
# Processing Record24 of Set 12 | laela
# Processing Record25 of Set 12 | madhupur
# Processing Record26 of Set 12 | turka
# Processing Record27 of Set 12 | kolno
# Processing Record28 of Set 12 | rognan
# Processing Record29 of Set 12 | vardo
# Processing Record30 of Set 12 | khomeyn
# Processing Record31 of Set 12 | thunder bay
# Processing Record32 of Set 12 | pilao arcado
# City not found. Skipping ...
# Processing Record33 of Set 12 | santa fe
# Processing Record34 of Set 12 | berea
# Processing Record35 of Set 12 | honiara
# Processing Record36 of Set 12 | mnogovershinnyy
# Processing Record37 of Set 12 | tolaga bay
# Processing Record38 of Set 12 | port elizabeth
# Processing Record39 of Set 12 | xining
# Processing Record40 of Set 12 | viedma
# Processing Record41 of Set 12 | sibolga
# Processing Record42 of Set 12 | cape elizabeth
# City not found. Skipping ...
# Processing Record43 of Set 12 | we
# City not found. Skipping ...
# Processing Record44 of Set 12 | abha
# Processing Record45 of Set 12 | puerto escondido
# Processing Record46 of Set 12 | huazolotitlan
# City not found. Skipping ...
# Processing Record47 of Set 12 | elban
# Processing Record48 of Set 12 | muros
# Processing Record49 of Set 12 | valdosta
# Processing Record50 of Set 12 | mataquescuintla
# Processing Record1 of Set 13 | barcelos
# Processing Record2 of Set 13 | lloydminster
# Processing Record3 of Set 13 | nizhneyansk
# City not found. Skipping ...
# Processing Record4 of Set 13 | grand gaube
# Processing Record5 of Set 13 | aswan
# Processing Record6 of Set 13 | bargal
# City not found. Skipping ...
# Processing Record7 of Set 13 | opunake
# Processing Record8 of Set 13 | mae hong son
# Processing Record9 of Set 13 | kharhial
# Processing Record10 of Set 13 | zavyalovo
# Processing Record11 of Set 13 | kamloops
# Processing Record12 of Set 13 | kysyl-syr
# Processing Record13 of Set 13 | barberton
# Processing Record14 of Set 13 | markova
# Processing Record15 of Set 13 | cockburn town
# Processing Record16 of Set 13 | nsanje
# Processing Record17 of Set 13 | halifax
# Processing Record18 of Set 13 | shemonaikha
# Processing Record19 of Set 13 | gat
# Processing Record20 of Set 13 | bo
# City not found. Skipping ...
# Processing Record21 of Set 13 | kieta
# Processing Record22 of Set 13 | kloulklubed
# Processing Record23 of Set 13 | port macquarie
# Processing Record24 of Set 13 | hadgaon
# Processing Record25 of Set 13 | brigham city
# Processing Record26 of Set 13 | tevriz
# Processing Record27 of Set 13 | yining
# Processing Record28 of Set 13 | tahe
# Processing Record29 of Set 13 | afyonkarahisar
# Processing Record30 of Set 13 | waipawa
# Processing Record31 of Set 13 | tiznit
# Processing Record32 of Set 13 | coahuayana
# Processing Record33 of Set 13 | port shepstone
# Processing Record34 of Set 13 | kuldur
# Processing Record35 of Set 13 | ambilobe
# Processing Record36 of Set 13 | roma
# Processing Record37 of Set 13 | san carlos de bariloche
# Processing Record38 of Set 13 | wyndham
# Processing Record39 of Set 13 | vorukh
# Processing Record40 of Set 13 | san blas
# Processing Record41 of Set 13 | bansang
# Processing Record42 of Set 13 | hirara
# Processing Record43 of Set 13 | arrifes
# Processing Record44 of Set 13 | san ramon
# Processing Record45 of Set 13 | alta floresta
# Processing Record46 of Set 13 | barvinkove
# Processing Record47 of Set 13 | camana
# Processing Record48 of Set 13 | muswellbrook
# Processing Record49 of Set 13 | haverfordwest
# Processing Record50 of Set 13 | san ignacio
# Processing Record1 of Set 14 | svetlaya
# Processing Record2 of Set 14 | cabo san lucas
# Processing Record3 of Set 14 | gland
# Processing Record4 of Set 14 | coos bay
# Processing Record5 of Set 14 | alamos
# Processing Record6 of Set 14 | marcona
# City not found. Skipping ...
# Processing Record7 of Set 14 | krynychky
# Processing Record8 of Set 14 | zhigalovo
# Processing Record9 of Set 14 | nainpur
# Processing Record10 of Set 14 | schwerte
# Processing Record11 of Set 14 | bhachau
# Processing Record12 of Set 14 | amaraji
# Processing Record13 of Set 14 | codrington
# Processing Record14 of Set 14 | tommot
# Processing Record15 of Set 14 | gisborne
# Processing Record16 of Set 14 | cabra
# Processing Record17 of Set 14 | la orilla
# Processing Record18 of Set 14 | itarema
# Processing Record19 of Set 14 | fountain hills
# Processing Record20 of Set 14 | imisli
# City not found. Skipping ...
# Processing Record21 of Set 14 | poplar bluff
# Processing Record22 of Set 14 | chernyshevskiy
# Processing Record23 of Set 14 | mandalgovi
# Processing Record24 of Set 14 | tole
# Processing Record25 of Set 14 | fortuna
# Processing Record26 of Set 14 | baruun-urt
# Processing Record27 of Set 14 | kavaratti
# Processing Record28 of Set 14 | constantine
# Processing Record29 of Set 14 | russell
# Processing Record30 of Set 14 | general roca
# Processing Record31 of Set 14 | voh
# Processing Record32 of Set 14 | el vigia
# Processing Record33 of Set 14 | uirauna
# Processing Record34 of Set 14 | gamba
# Processing Record35 of Set 14 | sinjar
# Processing Record36 of Set 14 | nuevo progreso
# Processing Record37 of Set 14 | guna
# Processing Record38 of Set 14 | luau
# Processing Record39 of Set 14 | ladybrand
# Processing Record40 of Set 14 | dwarka
# Processing Record41 of Set 14 | point pleasant
# Processing Record42 of Set 14 | inderborskiy
# City not found. Skipping ...
# Processing Record43 of Set 14 | pingliang
# Processing Record44 of Set 14 | campbellsville
# Processing Record45 of Set 14 | upington
# Processing Record46 of Set 14 | goure
# Processing Record47 of Set 14 | pisco
# Processing Record48 of Set 14 | portland
# Processing Record49 of Set 14 | hovd
# Processing Record50 of Set 14 | ust-koksa
# Processing Record1 of Set 15 | vung tau
# Processing Record2 of Set 15 | teguldet
# Processing Record3 of Set 15 | rorvik
# Processing Record4 of Set 15 | henties bay
# Processing Record5 of Set 15 | taoudenni
# Processing Record6 of Set 15 | brigantine
# Processing Record7 of Set 15 | susurluk
# Processing Record8 of Set 15 | acapetahua
# Processing Record9 of Set 15 | puerto lempira
# Processing Record10 of Set 15 | wote
# Processing Record11 of Set 15 | coutances
# Processing Record12 of Set 15 | tyret pervaya
# Processing Record13 of Set 15 | ikalamavony
# Processing Record14 of Set 15 | muroto
# Processing Record15 of Set 15 | kununurra
# Processing Record16 of Set 15 | balabac
# Processing Record17 of Set 15 | nogales
# Processing Record18 of Set 15 | popondetta
# Processing Record19 of Set 15 | ketchikan
# Processing Record20 of Set 15 | colwyn bay
# Processing Record21 of Set 15 | progreso
# Processing Record22 of Set 15 | sur
# Processing Record23 of Set 15 | alekseyevsk
# Processing Record24 of Set 15 | santander jimenez
# Processing Record25 of Set 15 | estacion coahuila
# Processing Record26 of Set 15 | zhoucheng
# Processing Record27 of Set 15 | loralai
# Processing Record28 of Set 15 | dhandhuka
# Processing Record29 of Set 15 | varadero
# Processing Record30 of Set 15 | plettenberg bay
# Processing Record31 of Set 15 | mozarlandia
# Processing Record32 of Set 15 | elk city
# Processing Record33 of Set 15 | tecoanapa
# Processing Record34 of Set 15 | tazovskiy
# Processing Record35 of Set 15 | launceston
# Processing Record36 of Set 15 | kaduqli
# Processing Record37 of Set 15 | talaya
# Processing Record38 of Set 15 | pinega
# Processing Record39 of Set 15 | sambava
# Processing Record40 of Set 15 | katsuura
# Processing Record41 of Set 15 | krasnyy chikoy
# Processing Record42 of Set 15 | sham churasi
# Processing Record43 of Set 15 | camopi
# Processing Record44 of Set 15 | antofagasta
# Processing Record45 of Set 15 | brae
# Processing Record46 of Set 15 | turayf
# Processing Record47 of Set 15 | lons
# Processing Record48 of Set 15 | saint-georges
# Processing Record49 of Set 15 | chenzhou
# Processing Record50 of Set 15 | severo-kurilsk
# Processing Record1 of Set 16 | santa marta
# Processing Record2 of Set 16 | fukuma
# Processing Record3 of Set 16 | nabire
# Processing Record4 of Set 16 | hargeysa
# Processing Record5 of Set 16 | kamskiye polyany
# Processing Record6 of Set 16 | dembi dolo
# Processing Record7 of Set 16 | kinablangan
# Processing Record8 of Set 16 | poum
# Processing Record9 of Set 16 | bouna
# Processing Record10 of Set 16 | promyshlennaya
# Processing Record11 of Set 16 | seoul
# Processing Record12 of Set 16 | port keats
# Processing Record13 of Set 16 | kingaroy
# Processing Record14 of Set 16 | boma
# Processing Record15 of Set 16 | bonaventure
# Processing Record16 of Set 16 | arequipa
# Processing Record17 of Set 16 | kropotkin
# Processing Record18 of Set 16 | kiruna
# Processing Record19 of Set 16 | matongo
# Processing Record20 of Set 16 | changji
# Processing Record21 of Set 16 | zilupe
# Processing Record22 of Set 16 | vostok
# ----------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
### Create a DataFrame from the city_data dictionary
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     66.11        77         100
# 1         Griffith      US  41.5284  -87.4237     69.73        95          40
# 2          Mataura      NZ -46.1927  168.8643     38.48        97         100
# 3         Flinders      AU -34.5833  150.8552     61.21        63           0
# 4       Georgetown      MY   5.4112  100.3354     89.55        72          20
# 5         Hermanus      ZA -34.4187   19.2345     58.42        67          98
# 6       Vila Velha      BR -20.3297  -40.2925     64.35        94          90
# 7     Krasnoselkup      RU  65.7000   82.4667     81.28        39           6
# 8          Kavieng      PG  -2.5744  150.7967     83.26        74          39
# 9         Bucerias      MX  20.7500 -105.3333     75.97       100         100
#
#    Wind Speed Current Description
# 0       11.36     overcast clouds
# 1        0.00    scattered clouds
# 2        2.66     overcast clouds
# 3        7.31           clear sky
# 4       11.50        thunderstorm
# 5        2.77     overcast clouds
# 6        4.61                mist
# 7        1.61           clear sky
# 8       15.10          light rain
# 9        3.80     overcast clouds

# %% [markdown]
# ### Create the Output as a CSV File from the DataFrame.

# %%
# Create the outup file (CSV)
output_data_file =  "Weather_Database/WeatherPy_Database.csv"

# Export the output file into a CSV file.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
